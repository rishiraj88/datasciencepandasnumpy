# %% [markdown]
# ### Array types and conversions between types

# %%
# %pip install numpy
import numpy as np
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
integers=np.array([101,202,303,404,505])

# %%
integers
# Out:
# array([101, 202, 303, 404, 505])

# %%
integers[0]
# Out:
# np.int64(101)

# %%
integers[0]=202
integers
# Out:
# array([202, 202, 303, 404, 505])

# %%
integers[0]=421.79
integers
# Out:
# array([421, 202, 303, 404, 505])

# %%
integers.dtype
# Out:
# dtype('int64')

# %%
smallerIntegers=np.array(integers,dtype=np.int8)

# %%
smallerIntegers
# Out:
# array([ -91,  -54,   47, -108,   -7], dtype=int8)

# %%
integers.nbytes
# Out:
# 40

# %%
smallerIntegers.nbytes
# Out:
# 5

# %%
# overflow = np.array([125,126,127,128,129], dtype = np.int8)
# overflow

# %%
floats=np.array([1.2,2.3,3.4,4.5])

# %%
floats
# Out:
# array([1.2, 2.3, 3.4, 4.5])

# %%
floats.dtype
# Out:
# dtype('float64')
