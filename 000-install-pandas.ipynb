# %%
# %pip freeze
# Out:
# asttokens==3.0.1
# colorama==0.4.6
# comm==0.2.3
# debugpy==1.8.20
# decorator==5.3.1
# executing==2.2.1
# ipykernel==7.2.0
# ipython==9.13.0
# ipython_pygments_lexers==1.1.1
# jedi==0.20.0
# jupyter_client==8.8.0
# jupyter_core==5.9.1
# matplotlib-inline==0.2.2
# nest-asyncio==1.6.0
# numpy==2.4.6
# packaging==26.2
# parso==0.8.7
# platformdirs==4.9.6
# prompt_toolkit==3.0.52
# psutil==7.2.2
# pure_eval==0.2.3
# Pygments==2.20.0
# python-dateutil==2.9.0.post0
# pyzmq==27.1.0
# six==1.17.0
# stack-data==0.6.3
# tornado==6.5.5
# traitlets==5.15.0
# wcwidth==0.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.9 MB 11.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.2/9.9 MB 11.4 MB/s eta 0:00:01
#    -------------------------- ------------- 6.6/9.9 MB 11.4 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 11.2 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
# ...
